# %%
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
from datetime import datetime
import pickle, json, sys, os, glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import chi2
from scipy import optimize
import subprocess

from astropy.coordinates     import SkyCoord
from lstchain.io.config      import get_standard_config
from ctapipe.io              import read_table
import tables

# Other auxiliar scripts
sys.path.insert(0, os.getcwd() + "/../scripts/")
import auxiliar as aux
import geometry as geom
import lstpipeline

import logging
logger = logging.getLogger(__name__)
logger.addHandler(logging.StreamHandler())
logger.setLevel(logging.INFO)

# %%
""" Source name in order to just complete the results file, and
in order to improve run organization."""
source_name = "crab"

# Standard paths for data in the IT cluster ---------
root_dl1 = "/fefs/aswg/data/real/DL1/*/v0.*/tailcut84/"
# root_rfs = "/fefs/aswg/data/models/AllSky/20240131_allsky_v0.10.5_all_dec_base/"
root_rfs = "/fefs/aswg/data/models/AllSky/20230927_v0.10.4_crab_tuned/"
# root_mcs = "/fefs/aswg/data/mc/DL2/AllSky/20240131_allsky_v0.10.5_all_dec_base/TestingDataset/"
root_mcs = "/fefs/aswg/data/mc/DL2/AllSky/20230927_v0.10.4_crab_tuned/TestingDataset/"

# Root path of this script
root = os.getcwd() + "/"
# Path to store the configuration file we are going to use
config_file = root + "config/standard_config.json"
# Path to store objects
root_objects = root + f"objects/"
# Data main directory
root_data = root + f"../../data/cherenkov_transparency_corrections/{source_name}/"

# Directories for the data
dir_dl1b_scaled = root_data + "dl1_scaled/"
dir_dl1m_scaled = root_data + "dl1_merged_scaled/"
dir_dl2_scaled  = root_data + "dl2_scaled/"
dir_dl2         = root_data + "dl2/"
dir_dl3_scaled_base = root_data + "dl3_scaled/"
dir_dl3_base    = root_data + "dl3/"
dir_irfs        = root_data + "irfs/"

# %%
dl3_runs_individual_scaled = glob.glob(dir_dl3_scaled_base + "*/dl3_LST-1.Run?????.fits")
dl3_runs_individual        = glob.glob(dir_dl3_base + "*/dl3_LST-1.Run?????.fits")

# %%
for dl3_runs, dir_move in zip([dl3_runs_individual_scaled, dl3_runs_individual], [dir_dl3_scaled_base, dir_dl3_base]):
    command = f"mv"
    
    for file in dl3_runs:
        command = command + f" {file}"
    
    # moving to main folder
    command = command + " " + dir_move
    
    subprocess.run(command, shell=True)

# %% [markdown]
# ### Add DL3 index files

# %%
command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_scaled_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

logger.info(f"\nFinished with the dl3 process")
# Out:
# lstchain_create_dl3_index_files --input-dl3-dir /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/ --overwrite
# 2024-03-06 14:32:36,356 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/hdu-index.fits.gz
# 2024-03-06 14:32:36,357 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/obs-index.fits.gz
# 2024-03-06 14:32:36,538 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,538 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU PSF
# 2024-03-06 14:32:36,555 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,556 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU PSF
# 2024-03-06 14:32:36,569 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,569 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU PSF
# 2024-03-06 14:32:36,582 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,582 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU PSF
# 2024-03-06 14:32:36,594 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,594 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU PSF
# 2024-03-06 14:32:36,605 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,606 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU PSF
# 2024-03-06 14:32:36,616 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,617 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU PSF
# 2024-03-06 14:32:36,628 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,628 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU PSF
# 2024-03-06 14:32:36,793 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,793 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU PSF
# 2024-03-06 14:32:36,802 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,802 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU PSF
# 2024-03-06 14:32:36,810 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,811 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU PSF
# 2024-03-06 14:32:36,819 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,819 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU PSF
# 2024-03-06 14:32:36,827 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,827 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU PSF
# 2024-03-06 14:32:36,836 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,836 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU PSF
# 2024-03-06 14:32:36,844 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,844 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU PSF
# 2024-03-06 14:32:36,853 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,853 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU PSF
# 2024-03-06 14:32:36,861 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,862 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU PSF
# 2024-03-06 14:32:36,870 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,871 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU PSF
# 2024-03-06 14:32:36,879 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,879 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU PSF
# 2024-03-06 14:32:36,887 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,888 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU PSF
# 2024-03-06 14:32:36,896 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,896 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU PSF
# 2024-03-06 14:32:36,905 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,905 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU PSF
# 2024-03-06 14:32:36,913 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,913 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU PSF
# 2024-03-06 14:32:36,921 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,921 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU PSF
# 2024-03-06 14:32:36,930 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,930 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU PSF
# 2024-03-06 14:32:36,938 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,939 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU PSF
# 2024-03-06 14:32:36,947 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,947 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU PSF
# 2024-03-06 14:32:36,956 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,956 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU PSF
# 2024-03-06 14:32:36,965 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,965 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU PSF
# 2024-03-06 14:32:36,974 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,974 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU PSF
# 2024-03-06 14:32:36,983 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,983 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU PSF
# 2024-03-06 14:32:36,992 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU BACKGROUND
# 2024-03-06 14:32:36,992 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU PSF
# 2024-03-06 14:32:37,001 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,002 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU PSF
# 2024-03-06 14:32:37,010 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,010 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU PSF
# 2024-03-06 14:32:37,018 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,018 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU PSF
# 2024-03-06 14:32:37,027 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3232 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,027 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3232 does not contain HDU PSF
# 2024-03-06 14:32:37,035 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3243 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,035 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3243 does not contain HDU PSF
# 2024-03-06 14:32:37,043 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,043 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU PSF
# 2024-03-06 14:32:37,051 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3271 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,051 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3271 does not contain HDU PSF
# 2024-03-06 14:32:37,059 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,060 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU PSF
# 2024-03-06 14:32:37,068 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,068 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU PSF
# 2024-03-06 14:32:37,076 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,077 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU PSF
# 2024-03-06 14:32:37,085 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,085 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU PSF
# 2024-03-06 14:32:37,094 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,094 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU PSF
# 2024-03-06 14:32:37,103 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3277 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,103 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3277 does not contain HDU PSF
# 2024-03-06 14:32:37,112 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3278 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,112 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3278 does not contain HDU PSF
# 2024-03-06 14:32:37,121 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3279 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37,121 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3279 does not contain HDU PSF
# 2024-03-06 14:32:37,131 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU BACKGROUND
# 2024-03-06 14:32:37