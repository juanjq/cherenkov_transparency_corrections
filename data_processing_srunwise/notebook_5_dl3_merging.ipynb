# %%
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
from datetime import datetime
import pickle, json, sys, os, glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import chi2
from scipy import optimize
import subprocess

from astropy.coordinates     import SkyCoord
from lstchain.io.config      import get_standard_config
from ctapipe.io              import read_table
import tables

# Other auxiliar scripts
sys.path.insert(0, os.getcwd() + "/../scripts/")
import auxiliar as aux
import geometry as geom
import lstpipeline

import logging
logger = logging.getLogger(__name__)
logger.addHandler(logging.StreamHandler())
logger.setLevel(logging.INFO)

# %%
""" Source name in order to just complete the results file, and
in order to improve run organization."""
source_name = "crab"

# Standard paths for data in the IT cluster ---------
root_dl1 = "/fefs/aswg/data/real/DL1/*/v0.*/tailcut84/"
root_rfs = "/fefs/aswg/data/models/AllSky/20230901_v0.10.4_allsky_base_prod/"
root_mcs = "/fefs/aswg/data/mc/DL2/AllSky/20230901_v0.10.4_allsky_base_prod/TestingDataset/"

# Root path of this script
root = os.getcwd() + "/"
# Path to store the configuration file we are going to use
config_file = root + "config/standard_config.json"
# Path to store objects
root_objects = root + f"objects/"
# Data main directory
root_data = root + f"../../data/cherenkov_transparency_corrections/{source_name}/"


# Directories for the data
dir_dl1b_scaled = root_data + "dl1_scaled/"
dir_dl1m_scaled = root_data + "dl1_merged_scaled/"
dir_dl2_scaled  = root_data + "dl2_scaled/"
dir_dl2         = root_data + "dl2/"
dir_dl3_scaled_base = root_data + "dl3_scaled/"
dir_dl3_base    = root_data + "dl3/"
dir_irfs        = root_data + "irfs/"

# %%
dl3_runs_individual_scaled = glob.glob(dir_dl3_scaled_base + "*/dl3_LST-1.Run?????.fits")
dl3_runs_individual        = glob.glob(dir_dl3_base + "*/dl3_LST-1.Run?????.fits")

# %%
for dl3_runs, dir_move in zip([dl3_runs_individual_scaled, dl3_runs_individual], [dir_dl3_scaled_base, dir_dl3_base]):
    command = f"cp"
    
    for file in dl3_runs:
        command = command + f" {file}"
    
    # moving to main folder
    command = command + " " + dir_move
    
    subprocess.run(command, shell=True)

# %% [markdown]
# ### Add DL3 index files

# %%
command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_scaled_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

logger.info(f"\nFinished with the dl3 process")
# Out:
# lstchain_create_dl3_index_files --input-dl3-dir /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/ --overwrite
# 2024-02-28 19:01:41,738 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/hdu-index.fits.gz
# 2024-02-28 19:01:41,741 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/obs-index.fits.gz
# 2024-02-28 19:01:41,827 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU BACKGROUND
# 2024-02-28 19:01:41,828 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU PSF
# 2024-02-28 19:01:41,864 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU BACKGROUND
# 2024-02-28 19:01:41,864 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU PSF
# 2024-02-28 19:01:41,875 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU BACKGROUND
# 2024-02-28 19:01:41,875 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU PSF
# 2024-02-28 19:01:41,886 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU BACKGROUND
# 2024-02-28 19:01:41,886 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU PSF
# 2024-02-28 19:01:41,897 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU BACKGROUND
# 2024-02-28 19:01:41,897 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU PSF
# 2024-02-28 19:01:41,907 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU BACKGROUND
# 2024-02-28 19:01:41,907 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU PSF
# 2024-02-28 19:01:41,918 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU BACKGROUND
# 2024-02-28 19:01:41,918 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU PSF
# 2024-02-28 19:01:41,928 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU BACKGROUND
# 2024-02-28 19:01:41,928 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU PSF
# 2024-02-28 19:01:42,164 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,164 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU PSF
# 2024-02-28 19:01:42,174 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,175 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU PSF
# 2024-02-28 19:01:42,185 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,186 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU PSF
# 2024-02-28 19:01:42,196 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,196 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU PSF
# 2024-02-28 19:01:42,205 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,205 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU PSF
# 2024-02-28 19:01:42,215 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,216 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU PSF
# 2024-02-28 19:01:42,225 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,226 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU PSF
# 2024-02-28 19:01:42,238 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,238 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU PSF
# 2024-02-28 19:01:42,249 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,250 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU PSF
# 2024-02-28 19:01:42,260 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,260 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU PSF
# 2024-02-28 19:01:42,270 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,270 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU PSF
# 2024-02-28 19:01:42,280 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,280 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU PSF
# 2024-02-28 19:01:42,290 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,290 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU PSF
# 2024-02-28 19:01:42,301 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,301 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU PSF
# 2024-02-28 19:01:42,310 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,310 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU PSF
# 2024-02-28 19:01:42,320 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,320 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU PSF
# 2024-02-28 19:01:42,331 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,331 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU PSF
# 2024-02-28 19:01:42,342 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,342 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU PSF
# 2024-02-28 19:01:42,352 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,352 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU PSF
# 2024-02-28 19:01:42,362 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,363 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU PSF
# 2024-02-28 19:01:42,373 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,373 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU PSF
# 2024-02-28 19:01:42,383 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,383 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU PSF
# 2024-02-28 19:01:42,393 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,393 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU PSF
# 2024-02-28 19:01:42,403 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,403 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU PSF
# 2024-02-28 19:01:42,413 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,413 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU PSF
# 2024-02-28 19:01:42,423 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,423 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU PSF
# 2024-02-28 19:01:42,434 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,434 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU PSF
# 2024-02-28 19:01:42,444 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,444 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU PSF
# 2024-02-28 19:01:42,454 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,454 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU PSF
# 2024-02-28 19:01:42,466 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,467 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU PSF
# 2024-02-28 19:01:42,478 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,478 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU PSF
# 2024-02-28 19:01:42,499 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,499 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU PSF
# 2024-02-28 19:01:42,511 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,512 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU PSF
# 2024-02-28 19:01:42,523 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,524 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU PSF
# 2024-02-28 19:01:42,534 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3319 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,534 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3319 does not contain HDU PSF
# 2024-02-28 19:01:42,544 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3321 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,544 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3321 does not contain HDU PSF
# 2024-02-28 19:01:42,555 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3328 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,555 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3328 does not contain HDU PSF
# 2024-02-28 19:01:42,565 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3329 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,566 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3329 does not contain HDU PSF
# 2024-02-28 19:01:42,576 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3338 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,576 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3338 does not contain HDU PSF
# 2024-02-28 19:01:42,587 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3355 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,587 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3355 does not contain HDU PSF
# 2024-02-28 19:01:42,597 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3356 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,597 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3356 does not contain HDU PSF
# 2024-02-28 19:01:42,607 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3373 does not contain HDU BACKGROUND
# 2024-02-28 19:01:42,608 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3373 does not contain HDU PSF
# lstchain_create_dl3_index_files --input-dl3-dir /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3_scaled/ --overwrite
# 2024-02-28 19:01:54,108 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3_scaled/hdu-index.fits.gz
# 2024-02-28 19:01:54,110 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3_scaled/obs-index.fits.gz
# 2024-02-28 19:01:54,232 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,232 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU PSF
# 2024-02-28 19:01:54,252 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,252 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU PSF
# 2024-02-28 19:01:54,266 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,267 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU PSF
# 2024-02-28 19:01:54,279 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,280 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU PSF
# 2024-02-28 19:01:54,291 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,291 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU PSF
# 2024-02-28 19:01:54,303 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,303 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU PSF
# 2024-02-28 19:01:54,313 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,314 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU PSF
# 2024-02-28 19:01:54,324 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,324 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU PSF
# 2024-02-28 19:01:54,464 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,465 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU PSF
# 2024-02-28 19:01:54,473 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,474 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU PSF
# 2024-02-28 19:01:54,483 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,483 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU PSF
# 2024-02-28 19:01:54,492 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,492 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU PSF
# 2024-02-28 19:01:54,501 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,501 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU PSF
# 2024-02-28 19:01:54,510 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,510 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU PSF
# 2024-02-28 19:01:54,520 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,520 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU PSF
# 2024-02-28 19:01:54,529 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,529 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU PSF
# 2024-02-28 19:01:54,538 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,538 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU PSF
# 2024-02-28 19:01:54,547 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,547 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU PSF
# 2024-02-28 19:01:54,557 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,557 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU PSF
# 2024-02-28 19:01:54,566 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,566 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU PSF
# 2024-02-28 19:01:54,575 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,575 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU PSF
# 2024-02-28 19:01:54,584 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,584 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU PSF
# 2024-02-28 19:01:54,594 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,594 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU PSF
# 2024-02-28 19:01:54,603 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,603 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU PSF
# 2024-02-28 19:01:54,612 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,612 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU PSF
# 2024-02-28 19:01:54,621 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,621 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU PSF
# 2024-02-28 19:01:54,630 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,630 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU PSF
# 2024-02-28 19:01:54,639 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,639 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU PSF
# 2024-02-28 19:01:54,651 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,651 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU PSF
# 2024-02-28 19:01:54,662 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,663 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU PSF
# 2024-02-28 19:01:54,672 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,673 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU PSF
# 2024-02-28 19:01:54,682 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,682 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU PSF
# 2024-02-28 19:01:54,692 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,692 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU PSF
# 2024-02-28 19:01:54,701 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,701 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU PSF
# 2024-02-28 19:01:54,710 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,710 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU PSF
# 2024-02-28 19:01:54,720 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,720 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU PSF
# 2024-02-28 19:01:54,729 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3271 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,729 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3271 does not contain HDU PSF
# 2024-02-28 19:01:54,739 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,739 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU PSF
# 2024-02-28 19:01:54,748 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,748 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU PSF
# 2024-02-28 19:01:54,757 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,758 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU PSF
# 2024-02-28 19:01:54,767 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,767 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU PSF
# 2024-02-28 19:01:54,781 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,782 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU PSF
# 2024-02-28 19:01:54,795 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,796 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU PSF
# 2024-02-28 19:01:54,808 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3319 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,809 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3319 does not contain HDU PSF
# 2024-02-28 19:01:54,821 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3321 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,821 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3321 does not contain HDU PSF
# 2024-02-28 19:01:54,833 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3328 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,833 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3328 does not contain HDU PSF
# 2024-02-28 19:01:54,844 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3329 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,845 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3329 does not contain HDU PSF
# 2024-02-28 19:01:54,856 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3338 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,856 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3338 does not contain HDU PSF
# 2024-02-28 19:01:54,866 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3355 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,866 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3355 does not contain HDU PSF
# 2024-02-28 19:01:54,876 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3356 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,876 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3356 does not contain HDU PSF
# 2024-02-28 19:01:54,885 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3373 does not contain HDU BACKGROUND
# 2024-02-28 19:01:54,885 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3373 does not contain HDU PSF
#
# Finished with the dl3 process
