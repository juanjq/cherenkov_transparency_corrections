# %%
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
from datetime import datetime
import pickle, json, sys, os, glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import chi2
from scipy import optimize
import subprocess

from astropy.coordinates     import SkyCoord
from lstchain.io.config      import get_standard_config
from ctapipe.io              import read_table
import tables

# Other auxiliar scripts
sys.path.insert(0, os.getcwd() + "/../scripts/")
import auxiliar as aux
import geometry as geom
import lstpipeline

import logging
logger = logging.getLogger(__name__)
logger.addHandler(logging.StreamHandler())
logger.setLevel(logging.INFO)

# %%
""" Source name in order to just complete the results file, and
in order to improve run organization."""
source_name = "crab"

# Standard paths for data in the IT cluster ---------
root_dl1 = "/fefs/aswg/data/real/DL1/*/v0.*/tailcut84/"
# root_rfs = "/fefs/aswg/data/models/AllSky/20240131_allsky_v0.10.5_all_dec_base/"
root_rfs = "/fefs/aswg/data/models/AllSky/20230927_v0.10.4_crab_tuned/"
# root_mcs = "/fefs/aswg/data/mc/DL2/AllSky/20240131_allsky_v0.10.5_all_dec_base/TestingDataset/"
root_mcs = "/fefs/aswg/data/mc/DL2/AllSky/20230927_v0.10.4_crab_tuned/TestingDataset/"

# Root path of this script
root = os.getcwd() + "/"
# Path to store the configuration file we are going to use
config_file = root + "config/standard_config.json"
# Path to store objects
root_objects = root + f"objects/"
# Data main directory
root_data = root + f"../../data/cherenkov_transparency_corrections/{source_name}/"


# Directories for the data
dir_dl1b_scaled = root_data + "dl1_scaled/"
dir_dl1m_scaled = root_data + "dl1_merged_scaled/"
dir_dl2_scaled  = root_data + "dl2_scaled/"
dir_dl2         = root_data + "dl2/"
dir_dl3_scaled_base = root_data + "dl3_scaled/"
dir_dl3_base    = root_data + "dl3/"
dir_irfs        = root_data + "irfs/"

# %%
dl3_runs_individual_scaled = glob.glob(dir_dl3_scaled_base + "*/dl3_LST-1.Run?????.fits")
dl3_runs_individual        = glob.glob(dir_dl3_base + "*/dl3_LST-1.Run?????.fits")

# %%
for dl3_runs, dir_move in zip([dl3_runs_individual_scaled, dl3_runs_individual], [dir_dl3_scaled_base, dir_dl3_base]):
    command = f"cp"
    
    for file in dl3_runs:
        command = command + f" {file}"
    
    # moving to main folder
    command = command + " " + dir_move
    
    subprocess.run(command, shell=True)
# Out:
# cp: missing destination file operand after ‘/fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3_scaled/’
# Try 'cp --help' for more information.
# cp: missing destination file operand after ‘/fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/’
# Try 'cp --help' for more information.

# %% [markdown]
# ### Add DL3 index files

# %%
command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_scaled_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

logger.info(f"\nFinished with the dl3 process")
# Out:
# lstchain_create_dl3_index_files --input-dl3-dir /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/ --overwrite
# 2024-03-04 17:49:14,475 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/hdu-index.fits.gz
# 2024-03-04 17:49:14,476 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/obs-index.fits.gz
# 2024-03-04 17:49:14,796 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU BACKGROUND
# 2024-03-04 17:49:14,796 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU PSF
# 2024-03-04 17:49:14,992 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU BACKGROUND
# 2024-03-04 17:49:14,993 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU PSF
# 2024-03-04 17:49:15,117 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU BACKGROUND
# 2024-03-04 17:49:15,117 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU PSF
# 2024-03-04 17:49:15,288 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU BACKGROUND
# 2024-03-04 17:49:15,288 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU PSF
# 2024-03-04 17:49:15,451 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU BACKGROUND
# 2024-03-04 17:49:15,451 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU PSF
# 2024-03-04 17:49:15,644 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU BACKGROUND
# 2024-03-04 17:49:15,644 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU PSF
# 2024-03-04 17:49:15,802 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU BACKGROUND
# 2024-03-04 17:49:15,803 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU PSF
# 2024-03-04 17:49:15,930 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU BACKGROUND
# 2024-03-04 17:49:15,930 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU PSF
# 2024-03-04 17:49:16,214 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU BACKGROUND
# 2024-03-04 17:49:16,215 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU PSF
# 2024-03-04 17:49:16,333 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU BACKGROUND
# 2024-03-04 17:49:16,333 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU PSF
# 2024-03-04 17:49:16,495 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU BACKGROUND
# 2024-03-04 17:49:16,495 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU PSF
# 2024-03-04 17:49:16,703 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU BACKGROUND
# 2024-03-04 17:49:16,704 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU PSF
# 2024-03-04 17:49:16,798 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU BACKGROUND
# 2024-03-04 17:49:16,799 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU PSF
# 2024-03-04 17:49:17,533 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU BACKGROUND
# 2024-03-04 17:49:17,534 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU PSF
# 2024-03-04 17:49:17,625 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU BACKGROUND
# 2024-03-04 17:49:17,626 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU PSF
# 2024-03-04 17:49:17,717 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU BACKGROUND
# 2024-03-04 17:49:17,717 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU PSF
# 2024-03-04 17:49:17,823 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU BACKGROUND
# 2024-03-04 17:49:17,823 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU PSF
# 2024-03-04 17:49:17,954 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU BACKGROUND
# 2024-03-04 17:49:17,954 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU PSF
# 2024-03-04 17:49:18,070 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,071 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU PSF
# 2024-03-04 17:49:18,165 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,165 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU PSF
# 2024-03-04 17:49:18,257 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,257 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU PSF
# 2024-03-04 17:49:18,362 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,362 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU PSF
# 2024-03-04 17:49:18,472 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,472 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU PSF
# 2024-03-04 17:49:18,635 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,636 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU PSF
# 2024-03-04 17:49:18,772 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,772 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU PSF
# 2024-03-04 17:49:18,854 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,855 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU PSF
# 2024-03-04 17:49:18,920 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU BACKGROUND
# 2024-03-04 17:49:18,921 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU PSF
# 2024-03-04 17:49:19,096 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU BACKGROUND
# 2024-03-04 17:49:19,097 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU PSF
# 2024-03-04 17:49:19,253 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU BACKGROUND
# 2024-03-04 17:49:19,253 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU PSF
# 2024-03-04 17:49:19,745 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU BACKGROUND
# 2024-03-04 17:49:19,746 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU PSF
# 2024-03-04 17:49:19,845 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU BACKGROUND
# 2024-03-04 17:49:19,845 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU PSF
# 2024-03-04 17:49:19,966 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU BACKGROUND
# 2024-03-04 17:49:19,967 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU PSF
# 2024-03-04 17:49:20,058 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU BACKGROUND
# 2024-03-04 17:49:20,059 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU PSF
# 2024-03-04 17:49:20,184 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU BACKGROUND
# 2024-03-04 17:49:20,185 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU PSF
# 2024-03-04 17:49:20,287 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU BACKGROUND
# 2024-03-04 17:49:20,287 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU PSF
# 2024-03-04 17:49:20,831 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU BACKGROUND
# 2024-03-04 17:49:20,832 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU PSF
# 2024-03-04 17:49:21,313 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU BACKGROUND
# 2024-03-04 17:49:21,313 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU PSF
# 2024-03-04 17:49:21,430 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU BACKGROUND
# 2024-03-04 17:49:21,431 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU PSF
# 2024-03-04 17:49:21,523 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU BACKGROUND
# 2024-03-04 17:49:21,524 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU PSF
# 2024-03-04 17:49:21,656 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU BACKGROUND
# 2024-03-04 17:49:21,657 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU PSF
# 2024-03-04 17:49:21,991 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU BACKGROUND
# 2024-03-04 17:49:21,991 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU PSF
# 2024-03-04 17:49:22,086 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU BACKGROUND
# 2024-03-04 17:49:22,086 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU PSF
# 2024-03-04 17:49:22,329 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3319 does not contain HDU BACKGROUND
# 2024-03-04 17:49:22,330 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3319 does not contain HDU PSF
# 2024-03-04 17:49:22,591 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3321 does not contain HDU BACKGROUND
# 2024-03-04 17:49:22,591 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3321 does not contain HDU PSF
# 2024-03-04 17:49:22,710 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3328 does not contain HDU BACKGROUND
# 2024-03-04 17:49:22,711 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3328 does not contain HDU PSF
# 2024-03-04 17:49:22,844 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3329 does not contain HDU BACKGROUND
# 2024-03-04 17:49:22,844 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3329 does not contain HDU PSF
# 2024-03-04 17:49:23,007 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3338 does not contain HDU BACKGROUND
# 2024-03-04 17:49:23,007 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3338 does not contain HDU PSF
# 2024-03-04 17:49:23,171 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3355 does not contain HDU BACKGROUND
# 2024-03-04 17:49:23,171 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3355 does not contain HDU PSF
# 2024-03-04 17:49:23,271 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3356 does not contain HDU BACKGROUND
# 2024-03-04 17:49:23,271 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3356 does not contain HDU PSF
# 2024-03-04 17:49:23,761 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3373 does not contain HDU BACKGROUND
# 2024-03-04 17:49:23,762 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3373 does not contain HDU PSF
# lstchain_create_dl3_index_files --input-dl3-dir /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3_scaled/ --overwrite
# 2024-03-04 17:49:34,758 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3_scaled/hdu-index.fits.gz
# 2024-03-04 17:49:34,759 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3_scaled/obs-index.fits.gz
# 2024-03-04 17:49:34,908 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU BACKGROUND
# 2024-03-04 17:49:34,908 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU PSF
# 2024-03-04 17:49:35,131 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU BACKGROUND
# 2024-03-04 17:49:35,132 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU PSF
# 2024-03-04 17:49:35,273 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU BACKGROUND
# 2024-03-04 17:49:35,273 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU PSF
# 2024-03-04 17:49:35,389 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU BACKGROUND
# 2024-03-04 17:49:35,390 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU PSF
# 2024-03-04 17:49:35,560 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU BACKGROUND
# 2024-03-04 17:49:35,561 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU PSF
# 2024-03-04 17:49:35,679 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU BACKGROUND
# 2024-03-04 17:49:35,679 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU PSF
# 2024-03-04 17:49:35,875 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU BACKGROUND
# 2024-03-04 17:49:35,875 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU PSF
# 2024-03-04 17:49:35,986 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU BACKGROUND
# 2024-03-04 17:49:35,987 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU PSF
# 2024-03-04 17:49:36,329 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU BACKGROUND
# 2024-03-04 17:49:36,329 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU PSF
# 2024-03-04 17:49:36,817 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU BACKGROUND
# 2024-03-04 17:49:36,817 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU PSF
# 2024-03-04 17:49:36,908 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU BACKGROUND
# 2024-03-04 17:49:36,908 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU PSF
# 2024-03-04 17:49:37,013 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU BACKGROUND
# 2024-03-04 17:49:37,013 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU PSF
# 2024-03-04 17:49:37,119 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU BACKGROUND
# 2024-03-04 17:49:37,119 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU PSF
# 2024-03-04 17:49:37,219 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU BACKGROUND
# 2024-03-04 17:49:37,220 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU PSF
# 2024-03-04 17:49:37,343 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU BACKGROUND
# 2024-03-04 17:49:37,343 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU PSF
# 2024-03-04 17:49:37,459 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU BACKGROUND
# 2024-03-04 17:49:37,460 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU PSF
# 2024-03-04 17:49:38,339 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU BACKGROUND
# 2024-03-04 17:49:38,339 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU PSF
# 2024-03-04 17:49:38,503 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU BACKGROUND
# 2024-03-04 17:49:38,504 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU PSF
# 2024-03-04 17:49:39,809 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU BACKGROUND
# 2024-03-04 17:49:39,810 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU PSF
# 2024-03-04 17:49:39,937 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU BACKGROUND
# 2024-03-04 17:49:39,937 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU PSF
# 2024-03-04 17:49:40,198 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU BACKGROUND
# 2024-03-04 17:49:40,198 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU PSF
# 2024-03-04 17:49:40,360 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU BACKGROUND
# 2024-03-04 17:49:40,361 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU PSF
# 2024-03-04 17:49:40,922 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU BACKGROUND
# 2024-03-04 17:49:40,922 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU PSF
# 2024-03-04 17:49:41,078 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU BACKGROUND
# 2024-03-04 17:49:41,078 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU PSF
# 2024-03-04 17:49:41,208 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU BACKGROUND
# 2024-03-04 17:49:41,208 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU PSF
# 2024-03-04 17:49:41,417 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU BACKGROUND
# 2024-03-04 17:49:41,417 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU PSF
# 2024-03-04 17:49:41,558 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU BACKGROUND
# 2024-03-04 17:49:41,558 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU PSF
# 2024-03-04 17:49:41,665 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU BACKGROUND
# 2024-03-04 17:49:41,666 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU PSF
# 2024-03-04 17:49:41,809 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU BACKGROUND
# 2024-03-04 17:49:41,809 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU PSF
# 2024-03-04 17:49:41,930 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU BACKGROUND
# 2024-03-04 17:49:41,930 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU PSF
# 2024-03-04 17:49:42,058 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU BACKGROUND
# 2024-03-04 17:49:42,058 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU PSF
# 2024-03-04 17:49:42,152 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU BACKGROUND
# 2024-03-04 17:49:42,153 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU PSF
# 2024-03-04 17:49:42,277 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU BACKGROUND
# 2024-03-04 17:49:42,277 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU PSF
# 2024-03-04 17:49:42,384 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU BACKGROUND
# 2024-03-04 17:49:42,385 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3096 does not contain HDU PSF
# 2024-03-04 17:49:42,507 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU BACKGROUND
# 2024-03-04 17:49:42,507 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3231 does not contain HDU PSF
# 2024-03-04 17:49:42,614 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU BACKGROUND
# 2024-03-04 17:49:42,615 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3270 does not contain HDU PSF
# 2024-03-04 17:49:42,878 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3271 does not contain HDU BACKGROUND
# 2024-03-04 17:49:42,879 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3271 does not contain HDU PSF
# 2024-03-04 17:49:43,030 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU BACKGROUND
# 2024-03-04 17:49:43,031 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3272 does not contain HDU PSF
# 2024-03-04 17:49:43,560 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU BACKGROUND
# 2024-03-04 17:49:43,560 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3273 does not contain HDU PSF
# 2024-03-04 17:49:43,680 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU BACKGROUND
# 2024-03-04 17:49:43,681 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3274 does not contain HDU PSF
# 2024-03-04 17:49:43,770 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU BACKGROUND
# 2024-03-04 17:49:43,771 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3275 does not contain HDU PSF
# 2024-03-04 17:49:43,918 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU BACKGROUND
# 2024-03-04 17:49:43,918 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3276 does not contain HDU PSF
# 2024-03-04 17:49:44,034 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU BACKGROUND
# 2024-03-04 17:49:44,034 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3318 does not contain HDU PSF
# 2024-03-04 17:49:44,147 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3319 does not contain HDU BACKGROUND
# 2024-03-04 17:49:44,147 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3319 does not contain HDU PSF
# 2024-03-04 17:49:44,261 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3321 does not contain HDU BACKGROUND
# 2024-03-04 17:49:44,261 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3321 does not contain HDU PSF
# 2024-03-04 17:49:44,446 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3328 does not contain HDU BACKGROUND
# 2024-03-04 17:49:44,447 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3328 does not contain HDU PSF
# 2024-03-04 17:49:45,013 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3329 does not contain HDU BACKGROUND
# 2024-03-04 17:49:45,014 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3329 does not contain HDU PSF
# 2024-03-04 17:49:45,277 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3338 does not contain HDU BACKGROUND
# 2024-03-04 17:49:45,277 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3338 does not contain HDU PSF
# 2024-03-04 17:49:45,477 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3355 does not contain HDU BACKGROUND
# 2024-03-04 17:49:45,477 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3355 does not contain HDU PSF
# 2024-03-04 17:49:45,562 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3356 does not contain HDU BACKGROUND
# 2024-03-04 17:49:45,562 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3356 does not contain HDU PSF
# 2024-03-04 17:49:45,717 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3373 does not contain HDU BACKGROUND
# 2024-03-04 17:49:45,718 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3373 does not contain HDU PSF
#
# Finished with the dl3 process
