# %%
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
from datetime import datetime
import pickle, json, sys, os, glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import chi2
from scipy import optimize
import subprocess

from astropy.coordinates import SkyCoord
from lstchain.io.config  import get_standard_config
from ctapipe.io          import read_table
import tables

# Other auxiliar scripts
sys.path.insert(0, os.getcwd() + "/../scripts/")
import auxiliar as aux
import geometry as geom
import lstpipeline

import logging
logger = logging.getLogger(__name__)
logger.addHandler(logging.StreamHandler())
logger.setLevel(logging.INFO)

# %%
""" Source name in order to just complete the results file, and
in order to improve run organization."""
source_name = "crab"

# Standard paths for data in the IT cluster ---------
root_dl1 = "/fefs/aswg/data/real/DL1/*/v0.*/tailcut84/"
root_rfs = "/fefs/aswg/data/models/AllSky/20230927_v0.10.4_crab_tuned/"
root_mcs = "/fefs/aswg/data/mc/DL2/AllSky/20230927_v0.10.4_crab_tuned/TestingDataset/"

# Root path of this script
root = os.getcwd() + "/"
# Path to store the configuration file we are going to use
config_file = root + "config/standard_config.json"
# Path to store objects
root_objects = root + f"objects/"
# Data main directory
root_data = root + f"../../data/cherenkov_transparency_corrections/{source_name}/"

# Directories for the data
dir_dl1b_scaled = root_data + "dl1_scaled/"
dir_dl1m_scaled = root_data + "dl1_merged_scaled/"
dir_dl2_scaled  = root_data + "dl2_scaled/"
dir_dl2         = root_data + "dl2/"
dir_dl3_scaled_base = root_data + "dl3_scaled/"
dir_dl3_base    = root_data + "dl3/"
dir_irfs        = root_data + "irfs/"

# %%
dl3_runs_individual_scaled = glob.glob(dir_dl3_scaled_base + "*/*.fits")
dl3_runs_individual = glob.glob(dir_dl3_base + "*/*.fits")

for dl3_runs, dir_move in zip([dl3_runs_individual_scaled, dl3_runs_individual], [dir_dl3_scaled_base, dir_dl3_base]):
    command = f"cp"
    
    for file in dl3_runs:
        command = command + f" {file}"
    
    # moving to main folder
    command = command + " " + dir_move
    
    subprocess.run(command, shell=True)

# %% [markdown]
# ### Add DL3 index files

# %%
command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_scaled_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

logger.info(f"\nFinished with the dl3 process")
# Out:
# lstchain_create_dl3_index_files --input-dl3-dir /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/ --overwrite
# 2024-03-13 13:50:34,684 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/hdu-index.fits.gz
# 2024-03-13 13:50:34,685 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/obs-index.fits.gz
# 2024-03-13 13:50:34,698 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,698 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU PSF
# 2024-03-13 13:50:34,712 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,712 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU PSF
# 2024-03-13 13:50:34,722 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,722 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU PSF
# 2024-03-13 13:50:34,732 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,732 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU PSF
# 2024-03-13 13:50:34,741 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,741 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU PSF
# 2024-03-13 13:50:34,750 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,750 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU PSF
# 2024-03-13 13:50:34,760 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,760 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU PSF
# 2024-03-13 13:50:34,769 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,769 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU PSF
# 2024-03-13 13:50:34,778 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,778 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU PSF
# 2024-03-13 13:50:34,788 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,788 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU PSF
# 2024-03-13 13:50:34,797 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU BACKGROUND
# 2024-03-13 13:50:34,797 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU PSF
# 2024-03-13 13:50:35,104 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,105 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU PSF
# 2024-03-13 13:50:35,115 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,115 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU PSF
# 2024-03-13 13:50:35,124 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,124 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU PSF
# 2024-03-13 13:50:35,134 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,134 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU PSF
# 2024-03-13 13:50:35,143 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,143 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU PSF
# 2024-03-13 13:50:35,152 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,153 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU PSF
# 2024-03-13 13:50:35,162 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,162 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU PSF
# 2024-03-13 13:50:35,171 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,171 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU PSF
# 2024-03-13 13:50:35,180 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,180 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU PSF
# 2024-03-13 13:50:35,189 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,189 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU PSF
# 2024-03-13 13:50:35,198 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,199 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU PSF
# 2024-03-13 13:50:35,207 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,208 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU PSF
# 2024-03-13 13:50:35,217 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,217 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU PSF
# 2024-03-13 13:50:35,227 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,227 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU PSF
# 2024-03-13 13:50:35,236 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,236 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU PSF
# 2024-03-13 13:50:35,245 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,245 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU PSF
# 2024-03-13 13:50:35,255 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,255 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU PSF
# 2024-03-13 13:50:35,264 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,264 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU PSF
# 2024-03-13 13:50:35,273 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,273 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3008 does not contain HDU PSF
# 2024-03-13 13:50:35,282 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,283 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3093 does not contain HDU PSF
# 2024-03-13 13:50:35,292 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,292 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3094 does not contain HDU PSF
# 2024-03-13 13:50:35,304 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU BACKGROUND
# 2024-03-13 13:50:35,304 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3095 does not contain HDU PSF
# 2024-03