# %%
import matplotlib.pyplot as plt
import numpy as np
import astropy.units as u
from datetime import datetime
import pickle, json, sys, os, glob
import pandas as pd
from scipy.optimize import curve_fit
from scipy.stats import chi2
from scipy import optimize
import subprocess

from astropy.coordinates import SkyCoord
from lstchain.io.config  import get_standard_config
from ctapipe.io          import read_table
import tables

# Other auxiliar scripts
sys.path.insert(0, os.getcwd() + "/../scripts/")
import auxiliar as aux
import geometry as geom
import lstpipeline

import logging
logger = logging.getLogger(__name__)
logger.addHandler(logging.StreamHandler())
logger.setLevel(logging.INFO)

# %%
""" Source name in order to just complete the results file, and
in order to improve run organization."""
source_name = "crab"

# Standard paths for data in the IT cluster ---------
root_dl1 = "/fefs/aswg/data/real/DL1/*/v0.*/tailcut84/"
# root_rfs = "/fefs/aswg/data/models/AllSky/20240131_allsky_v0.10.5_all_dec_base/"
root_rfs = "/fefs/aswg/data/models/AllSky/20230927_v0.10.4_crab_tuned/"
# root_mcs = "/fefs/aswg/data/mc/DL2/AllSky/20240131_allsky_v0.10.5_all_dec_base/TestingDataset/"
root_mcs = "/fefs/aswg/data/mc/DL2/AllSky/20230927_v0.10.4_crab_tuned/TestingDataset/"

# Root path of this script
root = os.getcwd() + "/"
# Path to store the configuration file we are going to use
config_file = root + "config/standard_config.json"
# Path to store objects
root_objects = root + f"objects/"
# Data main directory
root_data = root + f"../../data/cherenkov_transparency_corrections/{source_name}/"

# Directories for the data
dir_dl1b_scaled = root_data + "dl1_scaled/"
dir_dl1m_scaled = root_data + "dl1_merged_scaled/"
dir_dl2_scaled  = root_data + "dl2_scaled/"
dir_dl2         = root_data + "dl2/"
dir_dl3_scaled_base = root_data + "dl3_scaled/"
dir_dl3_base    = root_data + "dl3/"
dir_irfs        = root_data + "irfs/"

# %%
dl3_runs_individual_scaled = glob.glob(dir_dl3_scaled_base + "*/*.fits")
dl3_runs_individual = glob.glob(dir_dl3_base + "*/*.fits")

for dl3_runs, dir_move in zip([dl3_runs_individual_scaled, dl3_runs_individual], [dir_dl3_scaled_base, dir_dl3_base]):
    command = f"cp"
    
    for file in dl3_runs:
        command = command + f" {file}"
    
    # moving to main folder
    command = command + " " + dir_move
    
    subprocess.run(command, shell=True)
# Out:
# cp: missing destination file operand after ‘/fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/’
# Try 'cp --help' for more information.

# %% [markdown]
# ### Add DL3 index files

# %%
command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

command = f"lstchain_create_dl3_index_files --input-dl3-dir {dir_dl3_scaled_base} --overwrite"
logger.info(command)
subprocess.run(command, shell=True)

logger.info(f"\nFinished with the dl3 process")
# Out:
# lstchain_create_dl3_index_files --input-dl3-dir /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/ --overwrite
# 2024-03-11 16:20:53,460 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/hdu-index.fits.gz
# 2024-03-11 16:20:53,461 WARNING [lstchain.FITSIndexWriter] (lstchain_create_dl3_index_files.setup): Overwriting /fefs/aswg/workspace/juan.jimenez/cherenkov_transparency_corrections/data_processing_srunwise/../../data/cherenkov_transparency_corrections/crab/dl3/obs-index.fits.gz
# 2024-03-11 16:20:53,618 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU BACKGROUND
# 2024-03-11 16:20:53,618 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2914 does not contain HDU PSF
# 2024-03-11 16:20:53,907 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU BACKGROUND
# 2024-03-11 16:20:53,908 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2929 does not contain HDU PSF
# 2024-03-11 16:20:54,022 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU BACKGROUND
# 2024-03-11 16:20:54,022 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2930 does not contain HDU PSF
# 2024-03-11 16:20:54,223 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU BACKGROUND
# 2024-03-11 16:20:54,224 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2931 does not contain HDU PSF
# 2024-03-11 16:20:54,570 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU BACKGROUND
# 2024-03-11 16:20:54,570 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2932 does not contain HDU PSF
# 2024-03-11 16:20:55,185 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU BACKGROUND
# 2024-03-11 16:20:55,186 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2933 does not contain HDU PSF
# 2024-03-11 16:20:56,077 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU BACKGROUND
# 2024-03-11 16:20:56,078 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2934 does not contain HDU PSF
# 2024-03-11 16:20:56,389 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU BACKGROUND
# 2024-03-11 16:20:56,390 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2949 does not contain HDU PSF
# 2024-03-11 16:20:56,556 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU BACKGROUND
# 2024-03-11 16:20:56,556 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2950 does not contain HDU PSF
# 2024-03-11 16:20:56,628 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU BACKGROUND
# 2024-03-11 16:20:56,629 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2967 does not contain HDU PSF
# 2024-03-11 16:20:56,809 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU BACKGROUND
# 2024-03-11 16:20:56,809 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2968 does not contain HDU PSF
# 2024-03-11 16:20:57,158 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU BACKGROUND
# 2024-03-11 16:20:57,158 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2969 does not contain HDU PSF
# 2024-03-11 16:20:57,673 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU BACKGROUND
# 2024-03-11 16:20:57,673 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2970 does not contain HDU PSF
# 2024-03-11 16:20:58,014 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU BACKGROUND
# 2024-03-11 16:20:58,014 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2971 does not contain HDU PSF
# 2024-03-11 16:20:58,146 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU BACKGROUND
# 2024-03-11 16:20:58,146 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2972 does not contain HDU PSF
# 2024-03-11 16:20:58,424 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU BACKGROUND
# 2024-03-11 16:20:58,425 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2973 does not contain HDU PSF
# 2024-03-11 16:20:58,508 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU BACKGROUND
# 2024-03-11 16:20:58,508 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2974 does not contain HDU PSF
# 2024-03-11 16:20:58,587 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU BACKGROUND
# 2024-03-11 16:20:58,588 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2975 does not contain HDU PSF
# 2024-03-11 16:20:58,674 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU BACKGROUND
# 2024-03-11 16:20:58,674 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2976 does not contain HDU PSF
# 2024-03-11 16:20:58,782 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU BACKGROUND
# 2024-03-11 16:20:58,783 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2977 does not contain HDU PSF
# 2024-03-11 16:20:59,203 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU BACKGROUND
# 2024-03-11 16:20:59,203 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2988 does not contain HDU PSF
# 2024-03-11 16:20:59,427 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU BACKGROUND
# 2024-03-11 16:20:59,428 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2989 does not contain HDU PSF
# 2024-03-11 16:20:59,520 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU BACKGROUND
# 2024-03-11 16:20:59,521 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2990 does not contain HDU PSF
# 2024-03-11 16:20:59,697 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU BACKGROUND
# 2024-03-11 16:20:59,698 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2991 does not contain HDU PSF
# 2024-03-11 16:20:59,764 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU BACKGROUND
# 2024-03-11 16:20:59,764 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 2992 does not contain HDU PSF
# 2024-03-11 16:21:00,452 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU BACKGROUND
# 2024-03-11 16:21:00,452 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3004 does not contain HDU PSF
# 2024-03-11 16:21:00,576 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU BACKGROUND
# 2024-03-11 16:21:00,577 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3005 does not contain HDU PSF
# 2024-03-11 16:21:01,447 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU BACKGROUND
# 2024-03-11 16:21:01,447 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3006 does not contain HDU PSF
# 2024-03-11 16:21:01,623 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU BACKGROUND
# 2024-03-11 16:21:01,623 ERROR [lstchain.high_level.hdu_table] (hdu_table.create_hdu_index_hdu): Run 3007 does not contain HDU PSF
# 2024-03